# %% [markdown]
# <div class="alert alert-block alert-info">
#
# # Especialització de DataScience de la IT ACADEMY
# ### *Sprint4 - Exercici 1*
# #### Estandaritza, identifica i enumera cada un dels atributs / variables de l'estructura de l'arxiu "Web_access_log-akumenius.com" que trobaràs al repositori de GitHub "Data-sources".
# https://github.com/IT-Academy-BCN/Data-Science/blob/main/Data-sources/Web_access_log-akumenius.com.txt.7z
#
# #### Alumne: Jorge Prieto Rey
#
# <div>

# %%
import pandas as pd
import numpy as np
import re

# %%
#Llibreria per extreure fitxer .7z
import py7zr

# %%
with py7zr.SevenZipFile('Web_access_log-akumenius.com.txt.7z', mode='r') as z:
    z.extractall()

# %%
filename='Web_access_log-akumenius.com.txt'

# %%
fields = ['c1','c2','c3','c4','c5','c6','c7','c8','c9','c10','c11','c12','c13','c14']
    
data = pd.read_csv(filename, sep=' ', header=None, names=fields, na_values=['-'])
data
# Out:
# P:\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (7,12) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                        c1             c2  c3   c4                     c5  \
# 0               localhost      127.0.0.1 NaN  NaN  [23/Feb/2014:03:10:31
# 1               localhost      127.0.0.1 NaN  NaN  [23/Feb/2014:03:10:31
# 2               localhost      127.0.0.1 NaN  NaN  [23/Feb/2014:03:10:31
# 3               localhost      127.0.0.1 NaN  NaN  [23/Feb/2014:03:10:31
# 4               localhost      127.0.0.1 NaN  NaN  [23/Feb/2014:03:10:31
# ...                   ...            ...  ..  ...                    ...
# 261868  www.akumenius.com   5.255.253.53 NaN  NaN  [02/Mar/2014:03:05:39
# 261869  www.akumenius.com  74.86.158.107 NaN  NaN  [02/Mar/2014:03:09:52
# 261870          localhost      127.0.0.1 NaN  NaN  [02/Mar/2014:03:10:18
# 261871          localhost      127.0.0.1 NaN  NaN  [02/Mar/2014:03:10:18
# 261872          localhost      127.0.0.1 NaN  NaN  [02/Mar/2014:03:10:18
#
#             c6                  c7   c8      c9  c10  \
# 0       +0100]  OPTIONS * HTTP/1.0  200     NaN  NaN
# 1       +0100]  OPTIONS * HTTP/1.0  200     NaN  NaN
# 2       +0100]  OPTIONS * HTTP/1.0  200     NaN  NaN
# 3       +0100]  OPTIONS * HTTP/1.0  200     NaN  NaN
# 4       +0100]  OPTIONS * HTTP/1.0  200     NaN  NaN
# ...        ...                 ...  ...     ...  ...
# 261868  +0100]      GET / HTTP/1.1  200  7528.0  NaN
# 261869  +0100]     HEAD / HTTP/1.1  200     NaN  NaN
# 261870  +0100]  OPTIONS * HTTP/1.0  200     NaN  NaN
# 261871  +0100]  OPTIONS * HTTP/1.0  200     NaN  NaN
# 261872  +0100]  OPTIONS * HTTP/1.0  200     NaN  NaN
#
#                                                       c11     c12  c13  c14
# 0                      Apache (internal dummy connection)  VLOG=-  NaN  NaN
# 1                      Apache (internal dummy connection)  VLOG=-  NaN  NaN
# 2                      Apache (internal dummy connection)  VLOG=-  NaN  NaN
# 3                      Apache (internal dummy connection)  VLOG=-  NaN  NaN
# 4                      Apache (internal dummy connection)  VLOG=-  NaN  NaN
# ...                                                   ...     ...  ...  ...
# 261868  Mozilla/5.0 (compatible; YandexBot/3.0; +http:...  VLOG=-  NaN  NaN
# 261869  Mozilla/5.0+(compatible; UptimeRobot/2.0; http...  VLOG=-  NaN  NaN
# 261870                 Apache (internal dummy connection)  VLOG=-  NaN  NaN
# 261871                 Apache (internal dummy connection)  VLOG=-  NaN  NaN
# 261872                 Apache (internal dummy connection)  VLOG=-  NaN  NaN
#
# [261873 rows x 14 columns]

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# ### *Sprint4 - Exercici 2*
#
# Neteja, preprocesa, estructura i transforma (dataframe) les dades del registre d'Accés a la web.
#
# <div>

# %%
print('Total files: '+str(len(data)))
print('nombre de NaN en Columnes:')
data.isna().sum()
# Out:
# Total files: 261873
# nombre de NaN en Columnes:
# c1          0
# c2          0
# c3     261873
# c4     261846
# c5          0
# c6          0
# c7         37
# c8          0
# c9      42335
# c10     99545
# c11       221
# c12         0
# c13    261871
# c14    261873
# dtype: int64

# %%
#eliminem la columna c3 i c14 ja que no conte dades
data=data.drop(['c3','c14'],axis=1)

# %%
#renombrem les columnes del dataframe
newLength = len(fields)-2;
fields= fields[0:newLength]
data.columns = fields
data
# Out:
#                        c1             c2   c3                     c4      c5  \
# 0               localhost      127.0.0.1  NaN  [23/Feb/2014:03:10:31  +0100]
# 1               localhost      127.0.0.1  NaN  [23/Feb/2014:03:10:31  +0100]
# 2               localhost      127.0.0.1  NaN  [23/Feb/2014:03:10:31  +0100]
# 3               localhost      127.0.0.1  NaN  [23/Feb/2014:03:10:31  +0100]
# 4               localhost      127.0.0.1  NaN  [23/Feb/2014:03:10:31  +0100]
# ...                   ...            ...  ...                    ...     ...
# 261868  www.akumenius.com   5.255.253.53  NaN  [02/Mar/2014:03:05:39  +0100]
# 261869  www.akumenius.com  74.86.158.107  NaN  [02/Mar/2014:03:09:52  +0100]
# 261870          localhost      127.0.0.1  NaN  [02/Mar/2014:03:10:18  +0100]
# 261871          localhost      127.0.0.1  NaN  [02/Mar/2014:03:10:18  +0100]
# 261872          localhost      127.0.0.1  NaN  [02/Mar/2014:03:10:18  +0100]
#
#                         c6   c7      c8   c9  \
# 0       OPTIONS * HTTP/1.0  200     NaN  NaN
# 1       OPTIONS * HTTP/1.0  200     NaN  NaN
# 2       OPTIONS * HTTP/1.0  200     NaN  NaN
# 3       OPTIONS * HTTP/1.0  200     NaN  NaN
# 4       OPTIONS * HTTP/1.0  200     NaN  NaN
# ...                    ...  ...     ...  ...
# 261868      GET / HTTP/1.1  200  7528.0  NaN
# 261869     HEAD / HTTP/1.1  200     NaN  NaN
# 261870  OPTIONS * HTTP/1.0  200     NaN  NaN
# 261871  OPTIONS * HTTP/1.0  200     NaN  NaN
# 261872  OPTIONS * HTTP/1.0  200     NaN  NaN
#
#                                                       c10     c11  c12
# 0                      Apache (internal dummy connection)  VLOG=-  NaN
# 1                      Apache (internal dummy connection)  VLOG=-  NaN
# 2                      Apache (internal dummy connection)  VLOG=-  NaN
# 3                      Apache (internal dummy connection)  VLOG=-  NaN
# 4                      Apache (internal dummy connection)  VLOG=-  NaN
# ...                                                   ...     ...  ...
# 261868  Mozilla/5.0 (compatible; YandexBot/3.0; +http:...  VLOG=-  NaN
# 261869  Mozilla/5.0+(compatible; UptimeRobot/2.0; http...  VLOG=-  NaN
# 261870                 Apache (internal dummy connection)  VLOG=-  NaN
# 261871                 Apache (internal dummy connection)  VLOG=-  NaN
# 261872                 Apache (internal dummy connection)  VLOG=-  NaN
#
# [261873 rows x 12 columns]

# %%
data['c12'].value_counts(sort=False)
# Out:
# VLOG=-    2
# Name: c12, dtype: int64

# %%
data1 = data.loc[data['c12'] == 'VLOG=-']

# %%
data1.index
# Out:
# Int64Index([181473, 236496], dtype='int64')

# %% [markdown]
# #### Hi ha 2 files que no estan ben alineades perquè 'VLOG=-' esta a la columna c13

# %%
data[data1.index[0]-1:data1.index[0]+2]
# Out:
#                        c1              c2   c3                     c4      c5  \
# 181472  www.akumenius.com   74.86.158.106  NaN  [26/Feb/2014:23:44:15  +0100]
# 181473  www.akumenius.com      5.10.83.41  NaN  [26/Feb/2014:23:44:22  +0100]
# 181474  www.akumenius.com  220.181.108.96  NaN  [26/Feb/2014:23:44:31  +0100]
#
#                                                        c6         c7       c8  \
# 181472                                    HEAD / HTTP/1.1        200      NaN
# 181473  GET /escapadas/escapada-especial-san-valentin-...  HTTP/1.1"    200.0
# 181474                                     GET / HTTP/1.1        200  25030.0
#
#           c9                                                c10  \
# 181472   NaN  Mozilla/5.0+(compatible; UptimeRobot/2.0; http...
# 181473  3100                                                NaN
# 181474   NaN  Mozilla/5.0 (compatible; Baiduspider/2.0; +htt...
#
#                                                       c11     c12
# 181472                                             VLOG=-     NaN
# 181473  Mozilla/5.0 (compatible; AhrefsBot/5.0; +http:...  VLOG=-
# 181474                                             VLOG=-     NaN

# %%
data[data1.index[1]-1:data1.index[1]+2]
# Out:
#                        c1             c2   c3                     c4      c5  \
# 236495  www.akumenius.com  89.29.152.238  NaN  [28/Feb/2014:16:07:21  +0100]
# 236496  www.akumenius.com     5.10.83.11  NaN  [28/Feb/2014:16:07:20  +0100]
# 236497  www.akumenius.com  89.29.152.238  NaN  [28/Feb/2014:16:07:22  +0100]
#
#                                                        c6         c7     c8  \
# 236495                     POST /destinos-insert HTTP/1.1        200   26.0
# 236496  GET /escapadas/escapada-\al-salto-de-roldan\"-...  HTTP/1.1"  200.0
# 236497  GET /libraries/jqueryui/css/ui-lightness/image...        200  104.0
#
#                                c9  \
# 236495  http://www.akumenius.com/
# 236496                       3100
# 236497  http://www.akumenius.com/
#
#                                                       c10  \
# 236495  Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.3...
# 236496                                                NaN
# 236497  Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.3...
#
#                                                       c11     c12
# 236495                                             VLOG=-     NaN
# 236496  Mozilla/5.0 (compatible; AhrefsBot/5.0; +http:...  VLOG=-
# 236497                                             VLOG=-     NaN

# %%
#Juntem les columnes C6 i C7
data1['c6'] = data1['c6'].map(str)+""+data1['c7']
# Out:
# P:\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#Eliminen la columna C7
data1=data1.drop(['c7'],axis=1)
data1
# Out:
#                        c1          c2   c3                     c4      c5  \
# 181473  www.akumenius.com  5.10.83.41  NaN  [26/Feb/2014:23:44:22  +0100]
# 236496  www.akumenius.com  5.10.83.11  NaN  [28/Feb/2014:16:07:20  +0100]
#
#                                                        c6     c8    c9  c10  \
# 181473  GET /escapadas/escapada-especial-san-valentin-...  200.0  3100  NaN
# 236496  GET /escapadas/escapada-\al-salto-de-roldan\"-...  200.0  3100  NaN
#
#                                                       c11     c12
# 181473  Mozilla/5.0 (compatible; AhrefsBot/5.0; +http:...  VLOG=-
# 236496  Mozilla/5.0 (compatible; AhrefsBot/5.0; +http:...  VLOG=-

# %%
data1.loc[:,'b1'] = np.nan
#renombrem les columnes del dataframe
data1.columns = fields
data1
# Out:
#                        c1          c2   c3                     c4      c5  \
# 181473  www.akumenius.com  5.10.83.41  NaN  [26/Feb/2014:23:44:22  +0100]
# 236496  www.akumenius.com  5.10.83.11  NaN  [28/Feb/2014:16:07:20  +0100]
#
#                                                        c6     c7    c8   c9  \
# 181473  GET /escapadas/escapada-especial-san-valentin-...  200.0  3100  NaN
# 236496  GET /escapadas/escapada-\al-salto-de-roldan\"-...  200.0  3100  NaN
#
#                                                       c10     c11  c12
# 181473  Mozilla/5.0 (compatible; AhrefsBot/5.0; +http:...  VLOG=-  NaN
# 236496  Mozilla/5.0 (compatible; AhrefsBot/5.0; +http:...  VLOG=-  NaN

# %%
#reemplaçem les files 181473 i 236496
data.iloc[data1.index]=data1
data
# Out:
#                        c1             c2   c3                     c4      c5  \
# 0               localhost      127.0.0.1  NaN  [23/Feb/2014:03:10:31  +0100]
# 1               localhost      127.0.0.1  NaN  [23/Feb/2014:03:10:31  +0100]
# 2               localhost      127.0.0.1  NaN  [23/Feb/2014:03:10:31  +0100]
# 3               localhost      127.0.0.1  NaN  [23/Feb/2014:03:10:31  +0100]
# 4               localhost      127.0.0.1  NaN  [23/Feb/2014:03:10:31  +0100]
# ...                   ...            ...  ...                    ...     ...
# 261868  www.akumenius.com   5.255.253.53  NaN  [02/Mar/2014:03:05:39  +0100]
# 261869  www.akumenius.com  74.86.158.107  NaN  [02/Mar/2014:03:09:52  +0100]
# 261870          localhost      127.0.0.1  NaN  [02/Mar/2014:03:10:18  +0100]
# 261871          localhost      127.0.0.1  NaN  [02/Mar/2014:03:10:18  +0100]
# 261872          localhost      127.0.0.1  NaN  [02/Mar/2014:03:10:18  +0100]
#
#                         c6   c7    c8   c9  \
# 0       OPTIONS * HTTP/1.0  200   NaN  NaN
# 1       OPTIONS * HTTP/1.0  200   NaN  NaN
# 2       OPTIONS * HTTP/1.0  200   NaN  NaN
# 3       OPTIONS * HTTP/1.0  200   NaN  NaN
# 4       OPTIONS * HTTP/1.0  200   NaN  NaN
# ...                    ...  ...   ...  ...
# 261868      GET / HTTP/1.1  200  7528  NaN
# 261869     HEAD / HTTP/1.1  200   NaN  NaN
# 261870  OPTIONS * HTTP/1.0  200   NaN  NaN
# 261871  OPTIONS * HTTP/1.0  200   NaN  NaN
# 261872  OPTIONS * HTTP/1.0  200   NaN  NaN
#
#                                                       c10     c11  c12
# 0                      Apache (internal dummy connection)  VLOG=-  NaN
# 1                      Apache (internal dummy connection)  VLOG=-  NaN
# 2                      Apache (internal dummy connection)  VLOG=-  NaN
# 3                      Apache (internal dummy connection)  VLOG=-  NaN
# 4                      Apache (internal dummy connection)  VLOG=-  NaN
# ...                                                   ...     ...  ...
# 261868  Mozilla/5.0 (compatible; YandexBot/3.0; +http:...  VLOG=-  NaN
# 261869  Mozilla/5.0+(compatible; UptimeRobot/2.0; http...  VLOG=-  NaN
# 261870                 Apache (internal dummy connection)  VLOG=-  NaN
# 261871                 Apache (internal dummy connection)  VLOG=-  NaN
# 261872                 Apache (internal dummy connection)  VLOG=-  NaN
#
# [261873 rows x 12 columns]

# %%
#Verifiquem que la columna c12 no te valors
if ((len(data['c12'])) == (data['c12'].isnull().sum(axis=0))):
    print('Columna buida')
# Out:
# Columna buida

# %%
#eliminem la columna c12 ja que no conte dades
data=data.drop(['c12'],axis=1)
data
# Out:
#                        c1             c2   c3                     c4      c5  \
# 0               localhost      127.0.0.1  NaN  [23/Feb/2014:03:10:31  +0100]
# 1               localhost      127.0.0.1  NaN  [23/Feb/2014:03:10:31  +0100]
# 2               localhost      127.0.0.1  NaN  [23/Feb/2014:03:10:31  +0100]
# 3               localhost      127.0.0.1  NaN  [23/Feb/2014:03:10:31  +0100]
# 4               localhost      127.0.0.1  NaN  [23/Feb/2014:03:10:31  +0100]
# ...                   ...            ...  ...                    ...     ...
# 261868  www.akumenius.com   5.255.253.53  NaN  [02/Mar/2014:03:05:39  +0100]
# 261869  www.akumenius.com  74.86.158.107  NaN  [02/Mar/2014:03:09:52  +0100]
# 261870          localhost      127.0.0.1  NaN  [02/Mar/2014:03:10:18  +0100]
# 261871          localhost      127.0.0.1  NaN  [02/Mar/2014:03:10:18  +0100]
# 261872          localhost      127.0.0.1  NaN  [02/Mar/2014:03:10:18  +0100]
#
#                         c6   c7    c8   c9  \
# 0       OPTIONS * HTTP/1.0  200   NaN  NaN
# 1       OPTIONS * HTTP/1.0  200   NaN  NaN
# 2       OPTIONS * HTTP/1.0  200   NaN  NaN
# 3       OPTIONS * HTTP/1.0  200   NaN  NaN
# 4       OPTIONS * HTTP/1.0  200   NaN  NaN
# ...                    ...  ...   ...  ...
# 261868      GET / HTTP/1.1  200  7528  NaN
# 261869     HEAD / HTTP/1.1  200   NaN  NaN
# 261870  OPTIONS * HTTP/1.0  200   NaN  NaN
# 261871  OPTIONS * HTTP/1.0  200   NaN  NaN
# 261872  OPTIONS * HTTP/1.0  200   NaN  NaN
#
#                                                       c10     c11
# 0                      Apache (internal dummy connection)  VLOG=-
# 1                      Apache (internal dummy connection)  VLOG=-
# 2                      Apache (internal dummy connection)  VLOG=-
# 3                      Apache (internal dummy connection)  VLOG=-
# 4                      Apache (internal dummy connection)  VLOG=-
# ...                                                   ...     ...
# 261868  Mozilla/5.0 (compatible; YandexBot/3.0; +http:...  VLOG=-
# 261869  Mozilla/5.0+(compatible; UptimeRobot/2.0; http...  VLOG=-
# 261870                 Apache (internal dummy connection)  VLOG=-
# 261871                 Apache (internal dummy connection)  VLOG=-
# 261872                 Apache (internal dummy connection)  VLOG=-
#
# [261873 rows x 11 columns]

# %%
data['c11'].value_counts(sort=False)
# Out:
# VLOG=-    261873
# Name: c11, dtype: int64

# %%
#eliminem la columna c11 ja que totes les columnes contenen el mateix valors
data=data.drop(['c11'],axis=1)

# %% [markdown]
# #### Renombren les columnes amb la descripció dels elements del log ####

# %%
data
# Out:
#                        c1             c2   c3                     c4      c5  \
# 0               localhost      127.0.0.1  NaN  [23/Feb/2014:03:10:31  +0100]
# 1               localhost      127.0.0.1  NaN  [23/Feb/2014:03:10:31  +0100]
# 2               localhost      127.0.0.1  NaN  [23/Feb/2014:03:10:31  +0100]
# 3               localhost      127.0.0.1  NaN  [23/Feb/2014:03:10:31  +0100]
# 4               localhost      127.0.0.1  NaN  [23/Feb/2014:03:10:31  +0100]
# ...                   ...            ...  ...                    ...     ...
# 261868  www.akumenius.com   5.255.253.53  NaN  [02/Mar/2014:03:05:39  +0100]
# 261869  www.akumenius.com  74.86.158.107  NaN  [02/Mar/2014:03:09:52  +0100]
# 261870          localhost      127.0.0.1  NaN  [02/Mar/2014:03:10:18  +0100]
# 261871          localhost      127.0.0.1  NaN  [02/Mar/2014:03:10:18  +0100]
# 261872          localhost      127.0.0.1  NaN  [02/Mar/2014:03:10:18  +0100]
#
#                         c6   c7    c8   c9  \
# 0       OPTIONS * HTTP/1.0  200   NaN  NaN
# 1       OPTIONS * HTTP/1.0  200   NaN  NaN
# 2       OPTIONS * HTTP/1.0  200   NaN  NaN
# 3       OPTIONS * HTTP/1.0  200   NaN  NaN
# 4       OPTIONS * HTTP/1.0  200   NaN  NaN
# ...                    ...  ...   ...  ...
# 261868      GET / HTTP/1.1  200  7528  NaN
# 261869     HEAD / HTTP/1.1  200   NaN  NaN
# 261870  OPTIONS * HTTP/1.0  200   NaN  NaN
# 261871  OPTIONS * HTTP/1.0  200   NaN  NaN
# 261872  OPTIONS * HTTP/1.0  200   NaN  NaN
#
#                                                       c10
# 0                      Apache (internal dummy connection)
# 1                      Apache (internal dummy connection)
# 2                      Apache (internal dummy connection)
# 3                      Apache (internal dummy connection)
# 4                      Apache (internal dummy connection)
# ...                                                   ...
# 261868  Mozilla/5.0 (compatible; YandexBot/3.0; +http:...
# 261869  Mozilla/5.0+(compatible; UptimeRobot/2.0; http...
# 261870                 Apache (internal dummy connection)
# 261871                 Apache (internal dummy connection)
# 261872                 Apache (internal dummy connection)
#
# [261873 rows x 10 columns]

# %%
data['c3'].value_counts(sort=False)
# Out:
# clarcat    27
# Name: c3, dtype: int64

# %%
data1 = data.loc[data['c3'] == 'clarcat']
data1
# Out:
#                        c1             c2       c3                     c4  \
# 51797   www.akumenius.com  80.28.221.123  clarcat  [24/Feb/2014:09:54:07
# 51799   www.akumenius.com  80.28.221.123  clarcat  [24/Feb/2014:09:54:08
# 51809   www.akumenius.com  80.28.221.123  clarcat  [24/Feb/2014:09:54:08
# 51905   www.akumenius.com  80.28.221.123  clarcat  [24/Feb/2014:09:55:34
# 51906   www.akumenius.com  80.28.221.123  clarcat  [24/Feb/2014:09:55:34
# 51907   www.akumenius.com  80.28.221.123  clarcat  [24/Feb/2014:09:55:34
# 51923   www.akumenius.com  80.28.221.123  clarcat  [24/Feb/2014:09:55:54
# 51924   www.akumenius.com  80.28.221.123  clarcat  [24/Feb/2014:09:55:54
# 51926   www.akumenius.com  80.28.221.123  clarcat  [24/Feb/2014:09:55:54
# 51939   www.akumenius.com  80.28.221.123  clarcat  [24/Feb/2014:09:56:13
# 51940   www.akumenius.com  80.28.221.123  clarcat  [24/Feb/2014:09:56:13
# 51943   www.akumenius.com  80.28.221.123  clarcat  [24/Feb/2014:09:56:14
# 97210   www.akumenius.com  80.28.221.123  clarcat  [25/Feb/2014:09:53:27
# 97211   www.akumenius.com  80.28.221.123  clarcat  [25/Feb/2014:09:53:28
# 97215   www.akumenius.com  80.28.221.123  clarcat  [25/Feb/2014:09:53:28
# 153621  www.akumenius.com  80.28.221.123  clarcat  [26/Feb/2014:10:02:46
# 153622  www.akumenius.com  80.28.221.123  clarcat  [26/Feb/2014:10:02:46
# 153631  www.akumenius.com  80.28.221.123  clarcat  [26/Feb/2014:10:02:46
# 195142  www.akumenius.com  80.28.221.123  clarcat  [27/Feb/2014:12:48:52
# 195143  www.akumenius.com  80.28.221.123  clarcat  [27/Feb/2014:12:48:52
# 195149  www.akumenius.com  80.28.221.123  clarcat  [27/Feb/2014:12:48:52
# 196484  www.akumenius.com  80.28.221.123  clarcat  [27/Feb/2014:13:43:05
# 196486  www.akumenius.com  80.28.221.123  clarcat  [27/Feb/2014:13:43:06
# 196488  www.akumenius.com  80.28.221.123  clarcat  [27/Feb/2014:13:43:06
# 230605  www.akumenius.com  80.28.221.123  clarcat  [28/Feb/2014:09:41:38
# 230606  www.akumenius.com  80.28.221.123  clarcat  [28/Feb/2014:09:41:39
# 230610  www.akumenius.com  80.28.221.123  clarcat  [28/Feb/2014:09:41:39
#
#             c5                                                 c6   c7  \
# 51797   +0100]                              GET /awstats HTTP/1.1  200
# 51799   +0100]        GET /awstats.pl?framename=mainleft HTTP/1.1  200
# 51809   +0100]       GET /awstats.pl?framename=mainright HTTP/1.1  200
# 51905   +0100]  GET /awstats.pl?month=02&year=2013&output=main...  200
# 51906   +0100]  GET /awstats.pl?month=02&year=2013&output=main...  200
# 51907   +0100]  GET /awstats.pl?month=02&year=2013&output=main...  200
# 51923   +0100]  GET /awstats.pl?month=02&year=2012&output=main...  200
# 51924   +0100]  GET /awstats.pl?month=02&year=2012&output=main...  200
# 51926   +0100]  GET /awstats.pl?month=02&year=2012&output=main...  200
# 51939   +0100]  GET /awstats.pl?month=02&year=2014&output=main...  200
# 51940   +0100]  GET /awstats.pl?month=02&year=2014&output=main...  200
# 51943   +0100]  GET /awstats.pl?month=02&year=2014&output=main...  200
# 97210   +0100]                              GET /awstats HTTP/1.1  200
# 97211   +0100]        GET /awstats.pl?framename=mainleft HTTP/1.1  200
# 97215   +0100]       GET /awstats.pl?framename=mainright HTTP/1.1  200
# 153621  +0100]                              GET /awstats HTTP/1.1  200
# 153622  +0100]        GET /awstats.pl?framename=mainleft HTTP/1.1  200
# 153631  +0100]       GET /awstats.pl?framename=mainright HTTP/1.1  200
# 195142  +0100]                              GET /awstats HTTP/1.1  200
# 195143  +0100]        GET /awstats.pl?framename=mainleft HTTP/1.1  200
# 195149  +0100]       GET /awstats.pl?framename=mainright HTTP/1.1  200
# 196484  +0100]                              GET /awstats HTTP/1.1  200
# 196486  +0100]        GET /awstats.pl?framename=mainleft HTTP/1.1  200
# 196488  +0100]       GET /awstats.pl?framename=mainright HTTP/1.1  200
# 230605  +0100]                              GET /awstats HTTP/1.1  200
# 230606  +0100]        GET /awstats.pl?framename=mainleft HTTP/1.1  200
# 230610  +0100]       GET /awstats.pl?framename=mainright HTTP/1.1  200
#
#             c8                                                 c9  \
# 51797      996                                                NaN
# 51799    10066                   http://www.akumenius.com/awstats
# 51809   120843                   http://www.akumenius.com/awstats
# 51905     1146  http://www.akumenius.com/awstats.pl?framename=...
# 51906    12249  http://www.akumenius.com/awstats.pl?month=02&y...
# 51907   109613  http://www.akumenius.com/awstats.pl?month=02&y...
# 51923     1146  http://www.akumenius.com/awstats.pl?month=02&y...
# 51924    12249  http://www.akumenius.com/awstats.pl?month=02&y...
# 51926   108224  http://www.akumenius.com/awstats.pl?month=02&y...
# 51939     1146  http://www.akumenius.com/awstats.pl?month=02&y...
# 51940    12249  http://www.akumenius.com/awstats.pl?month=02&y...
# 51943   122007  http://www.akumenius.com/awstats.pl?month=02&y...
# 97210      996                                                NaN
# 97211    10066                   http://www.akumenius.com/awstats
# 97215   120914                   http://www.akumenius.com/awstats
# 153621     996                                                NaN
# 153622   10066                   http://www.akumenius.com/awstats
# 153631  120993                   http://www.akumenius.com/awstats
# 195142     996                                                NaN
# 195143   10066                   http://www.akumenius.com/awstats
# 195149  121262                   http://www.akumenius.com/awstats
# 196484     996                                                NaN
# 196486   10066                   http://www.akumenius.com/awstats
# 196488  121262                   http://www.akumenius.com/awstats
# 230605     996                                                NaN
# 230606   10066                   http://www.akumenius.com/awstats
# 230610  121317                   http://www.akumenius.com/awstats
#
#                                                       c10
# 51797   Mozilla/5.0 (X11; U; Linux i686; ca; rv:1.9.2....
# 51799   Mozilla/5.0 (X11; U; Linux i686; ca; rv:1.9.2....
# 51809   Mozilla/5.0 (X11; U; Linux i686; ca; rv:1.9.2....
# 51905   Mozilla/5.0 (X11; U; Linux i686; ca; rv:1.9.2....
# 51906   Mozilla/5.0 (X11; U; Linux i686; ca; rv:1.9.2....
# 51907   Mozilla/5.0 (X11; U; Linux i686; ca; rv:1.9.2....
# 51923   Mozilla/5.0 (X11; U; Linux i686; ca; rv:1.9.2....
# 51924   Mozilla/5.0 (X11; U; Linux i686; ca; rv:1.9.2....
# 51926   Mozilla/5.0 (X11; U; Linux i686; ca; rv:1.9.2....
# 51939   Mozilla/5.0 (X11; U; Linux i686; ca; rv:1.9.2....
# 51940   Mozilla/5.0 (X11; U; Linux i686; ca; rv:1.9.2....
# 51943   Mozilla/5.0 (X11; U; Linux i686; ca; rv:1.9.2....
# 97210   Mozilla/5.0 (X11; U; Linux i686; ca; rv:1.9.2....
# 97211   Mozilla/5.0 (X11; U; Linux i686; ca; rv:1.9.2....
# 97215   Mozilla/5.0 (X11; U; Linux i686; ca; rv:1.9.2....
# 153621  Mozilla/5.0 (X11; U; Linux i686; ca; rv:1.9.2....
# 153622  Mozilla/5.0 (X11; U; Linux i686; ca; rv:1.9.2....
# 153631  Mozilla/5.0 (X11; U; Linux i686; ca; rv:1.9.2....
# 195142  Mozilla/5.0 (X11; U; Linux i686; ca; rv:1.9.2....
# 195143  Mozilla/5.0 (X11; U; Linux i686; ca; rv:1.9.2....
# 195149  Mozilla/5.0 (X11; U; Linux i686; ca; rv:1.9.2....
# 196484  Mozilla/5.0 (X11; U; Linux i686; ca; rv:1.9.2....
# 196486  Mozilla/5.0 (X11; U; Linux i686; ca; rv:1.9.2....
# 196488  Mozilla/5.0 (X11; U; Linux i686; ca; rv:1.9.2....
# 230605  Mozilla/5.0 (X11; U; Linux i686; ca; rv:1.9.2....
# 230606  Mozilla/5.0 (X11; U; Linux i686; ca; rv:1.9.2....
# 230610  Mozilla/5.0 (X11; U; Linux i686; ca; rv:1.9.2....

# %%
#Eliminem la columna c3 perque no ens dona informació rellevant
data=data.drop(['c3'],axis=1)
data
# Out:
#                        c1             c2                     c4      c5  \
# 0               localhost      127.0.0.1  [23/Feb/2014:03:10:31  +0100]
# 1               localhost      127.0.0.1  [23/Feb/2014:03:10:31  +0100]
# 2               localhost      127.0.0.1  [23/Feb/2014:03:10:31  +0100]
# 3               localhost      127.0.0.1  [23/Feb/2014:03:10:31  +0100]
# 4               localhost      127.0.0.1  [23/Feb/2014:03:10:31  +0100]
# ...                   ...            ...                    ...     ...
# 261868  www.akumenius.com   5.255.253.53  [02/Mar/2014:03:05:39  +0100]
# 261869  www.akumenius.com  74.86.158.107  [02/Mar/2014:03:09:52  +0100]
# 261870          localhost      127.0.0.1  [02/Mar/2014:03:10:18  +0100]
# 261871          localhost      127.0.0.1  [02/Mar/2014:03:10:18  +0100]
# 261872          localhost      127.0.0.1  [02/Mar/2014:03:10:18  +0100]
#
#                         c6   c7    c8   c9  \
# 0       OPTIONS * HTTP/1.0  200   NaN  NaN
# 1       OPTIONS * HTTP/1.0  200   NaN  NaN
# 2       OPTIONS * HTTP/1.0  200   NaN  NaN
# 3       OPTIONS * HTTP/1.0  200   NaN  NaN
# 4       OPTIONS * HTTP/1.0  200   NaN  NaN
# ...                    ...  ...   ...  ...
# 261868      GET / HTTP/1.1  200  7528  NaN
# 261869     HEAD / HTTP/1.1  200   NaN  NaN
# 261870  OPTIONS * HTTP/1.0  200   NaN  NaN
# 261871  OPTIONS * HTTP/1.0  200   NaN  NaN
# 261872  OPTIONS * HTTP/1.0  200   NaN  NaN
#
#                                                       c10
# 0                      Apache (internal dummy connection)
# 1                      Apache (internal dummy connection)
# 2                      Apache (internal dummy connection)
# 3                      Apache (internal dummy connection)
# 4                      Apache (internal dummy connection)
# ...                                                   ...
# 261868  Mozilla/5.0 (compatible; YandexBot/3.0; +http:...
# 261869  Mozilla/5.0+(compatible; UptimeRobot/2.0; http...
# 261870                 Apache (internal dummy connection)
# 261871                 Apache (internal dummy connection)
# 261872                 Apache (internal dummy connection)
#
# [261873 rows x 9 columns]

# %% [markdown]
# #### La data en les columnes c4 i c5 representada el temps en dues part, separem la data i l'hora en una nova columna anomenada time i eliminem la columna de zona horaria. També eliminem les columnes c4 i c5 ####

# %%
time = data['c4'] + data['c5']
time_trimmed = time.map(lambda s: s.strip('[]').split('+')[0])
data['time'] = pd.to_datetime(time_trimmed, format='%d/%b/%Y:%H:%M:%S')
data=data.drop(['c4'],axis=1)
data=data.drop(['c5'],axis=1)

# %% [markdown]
# #### Separem la columna c6 en 3 columnes per "Protocol" + "command" i "path" ####

# %%
data_c6=data['c6'].str.split(expand=True)
data_c6.columns = ['command','path','protocol']
data_c6
# Out:
#         command path  protocol
# 0       OPTIONS    *  HTTP/1.0
# 1       OPTIONS    *  HTTP/1.0
# 2       OPTIONS    *  HTTP/1.0
# 3       OPTIONS    *  HTTP/1.0
# 4       OPTIONS    *  HTTP/1.0
# ...         ...  ...       ...
# 261868      GET    /  HTTP/1.1
# 261869     HEAD    /  HTTP/1.1
# 261870  OPTIONS    *  HTTP/1.0
# 261871  OPTIONS    *  HTTP/1.0
# 261872  OPTIONS    *  HTTP/1.0
#
# [261873 rows x 3 columns]

# %%
#verifiquem que la columna c9 conte les url
data['c9'].value_counts(sort=False)
# Out:
# http://www.akumenius.com/hotelDetailPopup/325/e/3                                                                                                                                                                                                                                                                    10
# http://www.akumenius.com/hotelDetailPopup/216055/b                                                                                                                                                                                                                                                                    2
# http://www.akumenius.com/booking/32182/e/1/1?i=h6LFj6mZYITfKmnztgvO4Kmm1VwDT41waBaUDL%2BS8k4%3D                                                                                                                                                                                                                      11
# http://www.akumenius.com/hoteles-baratos/ofertas-hotel-Nuevo-Astur-en-Sanxenxo-9690b-destinos.html                                                                                                                                                                                                                   47
# http://www.akumenius.com/destinos-caracteristicas/hoteles-baratos-en-Venecia_ITALIA-con-Pensi%C3%B3n-completa                                                                                                                                                                                                        16
#                                                                                                                                                                                                                                                                                                                    ...
# http://www.akumenius.com/hotel-list/102482/EP/ESCAPADA%20ESPECIAL%20SEMANA%20SANTA%20HOTEL%20PLAYAS%20DE%20GUARDAMAR/escapada?type=1                                                                                                                                                                                237
# http://www.akumenius.com/hoteles-baratos/hoteles-todo-incluido.html?gclid=CP7GvrSD7LwCFYUIwwoduBcAyQ                                                                                                                                                                                                                 49
# http://www.google.com/url?sa=t&rct=j&q=&esrc=s&frm=1&source=web&cd=1&ved=0CDcQFjAA&url=http%3A%2F%2Fwww.akumenius.com%2FdestinosCaracteristicas%2Fhoteles-baratos-en-Navarra_ESPA%25C3%2591A-con-Piscina-climatizada&ei=wq8LU_LoBIOb0QWzkICYCQ&usg=AFQjCNG-XfC5zY9BQ_z-6P7udZh1X_sMvQ&bvm=bv.61725948,d.d2k           2
# http://www.google.es/aclk?sa=L&ai=C1cZdQrwMU5WzN6GmjAb36YH4BIWf4bUEjZ-np4gBmrqOiuUBCAAQAVDEuMuJBWDV5dqCiAnIAQGpAjr6dSWWFLc-qgQlT9BxWtZ5AUKJqQq5JiGxtDjh5vuK8eyu58L3XehzU2f4E332C4AHkcqaE5AHAw&sig=AOD64_3wPzW2skebeqp6nyXGVfeNetnuag&rct=j&frm=1&q=semana+santa+2014&ved=0CC4Q0Qw&adurl=http://www.akumenius.com      1
# http://www.akumenius.com/destinosCaracteristicas/hoteles-baratos-en-Rostock_ALEMANIA-con-Disponibilidad-de-cobertura-para-tel%C3%A9fonos-m%C3%B3viles                                                                                                                                                                42
# Name: c9, Length: 2506, dtype: int64

# %%
data=data.drop(['c6'],axis=1) #Eliminar columna c6
data=pd.concat([data,data_c6],axis = 1)

# %%
#c7 http_code 
#c8 response bytes
#c10 user_agent
#c9 url
data.rename(columns = {'c1':'host','c2':'ip','c7':'http_code','c8' : 'response_bytes','c9':'url','c10':'user_agent'},inplace = True)
data
# Out:
#                      host             ip http_code response_bytes  url  \
# 0               localhost      127.0.0.1       200            NaN  NaN
# 1               localhost      127.0.0.1       200            NaN  NaN
# 2               localhost      127.0.0.1       200            NaN  NaN
# 3               localhost      127.0.0.1       200            NaN  NaN
# 4               localhost      127.0.0.1       200            NaN  NaN
# ...                   ...            ...       ...            ...  ...
# 261868  www.akumenius.com   5.255.253.53       200           7528  NaN
# 261869  www.akumenius.com  74.86.158.107       200            NaN  NaN
# 261870          localhost      127.0.0.1       200            NaN  NaN
# 261871          localhost      127.0.0.1       200            NaN  NaN
# 261872          localhost      127.0.0.1       200            NaN  NaN
#
#                                                user_agent                time  \
# 0                      Apache (internal dummy connection) 2014-02-23 03:10:31
# 1                      Apache (internal dummy connection) 2014-02-23 03:10:31
# 2                      Apache (internal dummy connection) 2014-02-23 03:10:31
# 3                      Apache (internal dummy connection) 2014-02-23 03:10:31
# 4                      Apache (internal dummy connection) 2014-02-23 03:10:31
# ...                                                   ...                 ...
# 261868  Mozilla/5.0 (compatible; YandexBot/3.0; +http:... 2014-03-02 03:05:39
# 261869  Mozilla/5.0+(compatible; UptimeRobot/2.0; http... 2014-03-02 03:09:52
# 261870                 Apache (internal dummy connection) 2014-03-02 03:10:18
# 261871                 Apache (internal dummy connection) 2014-03-02 03:10:18
# 261872                 Apache (internal dummy connection) 2014-03-02 03:10:18
#
#         command path  protocol
# 0       OPTIONS    *  HTTP/1.0
# 1       OPTIONS    *  HTTP/1.0
# 2       OPTIONS    *  HTTP/1.0
# 3       OPTIONS    *  HTTP/1.0
# 4       OPTIONS    *  HTTP/1.0
# ...         ...  ...       ...
# 261868      GET    /  HTTP/1.1
# 261869     HEAD    /  HTTP/1.1
# 261870  OPTIONS    *  HTTP/1.0
# 261871  OPTIONS    *  HTTP/1.0
# 261872  OPTIONS    *  HTTP/1.0
#
# [261873 rows x 10 columns]

# %%
#exemple de fila del dataframe
data.iloc[15452]
# Out:
# host                                              www.akumenius.com
# ip                                                    88.31.143.254
# http_code                                                       200
# response_bytes                                                  742
# url                             http://www.akumenius.com/hotel-list
# user_agent        Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# time                                            2014-02-23 12:51:43
# command                                                         GET
# path              /modules/raton/views/themes/bcoos/images/busca...
# protocol                                                   HTTP/1.1
# Name: 15452, dtype: object

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# ### *Sprint4 - Exercici 3*
#
# Geolocalitza les IP's.
#
# <div>

# %%
import requests
import json

# %%
# URL de la API
api_url = "http://ip-api.com/json/"

# %%
#lista ips
data_ips=(data['ip'].value_counts(sort=False)).index

# %%
data_ips
# Out:
# Index(['181.118.30.53', '157.56.93.62', '220.181.108.82', '46.236.24.53',
#        '85.136.169.148', '173.252.101.112', '79.108.184.134',
#        '220.181.108.115', '190.91.95.13', '84.79.214.214',
#        ...
#        '202.46.61.33', '87.221.33.120', '66.220.152.112', '217.16.255.159',
#        '177.68.141.25', '90.174.1.32', '199.30.20.5', '180.76.6.56',
#        '212.231.183.216', '54.234.37.0'],
#       dtype='object', length=2921)

# %%
data_ips[0]
# Out:
# '181.118.30.53'

# %%
# Definimos los parametros de respuesta que queremos obtener
parametros = 'status,country,countryCode,region,regionName,city,zip,lat,lon,timezone,isp,org,as,query'
data_Ip = {"fields":parametros}

# %%
def ip_scraping(ip=""):
 # Nos conectamos con la API
 res = requests.get(api_url+ip, data=data_Ip)
 # Obtenemos y procesamos la respuesta JSON
 api_json_res = json.loads(res.content)
 return api_json_res

# %%
ip_response = ip_scraping(data_ips[0])
ip_response
# Out:
# {'status': 'success',
#  'country': 'Argentina',
#  'countryCode': 'AR',
#  'region': 'M',
#  'regionName': 'Mendoza',
#  'city': 'Godoy Cruz',
#  'zip': '5501',
#  'lat': -32.9204,
#  'lon': -68.8293,
#  'timezone': 'America/Argentina/Mendoza',
#  'isp': 'Alpha Tel S.A.',
#  'org': 'Alpha Tel S.A',
#  'as': 'AS28114 Alpha Tel S.A.',
#  'query': '181.118.30.53'}

# %%
ip_df=pd.DataFrame([ip_scraping(data_ips[0])])

# %%
for ip in data_ips:
    ip_df = ip_df.append([ip_scraping(ip)],ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-71-591fe8fc1483> in <module>
#       1 for ip in data_ips:
# ----> 2     ip_df = ip_df.append([ip_scraping(ip)],ignore_index=True)
#
# <ipython-input-43-b3e952d09798> in ip_scraping(ip)
#       3  res = requests.get(api_url+ip, data=data_Ip)
#       4  # Obtenemos y procesamos la respuesta JSON
# ----> 5  api_json_res = json.loads(res.content)
#       6  return api_json_res
#
# P:\anaconda3\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# --> 348         return _default_decoder.decode(s)
#     349     if cls is None:
#     350         cls = JSONDecoder
#
# P:\anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# P:\anaconda3\lib\json\decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
ip_df
# Out:
#      status         country countryCode region  regionName               city  \
# 0   success       Argentina          AR      M     Mendoza         Godoy Cruz
# 1   success       Argentina          AR      M     Mendoza         Godoy Cruz
# 2   success   United States          US     WA  Washington  Quincy-moses Lake
# 3   success           China          CN     BJ     Beijing            Beijing
# 4   success  United Kingdom          GB    ENG     England             London
# ..      ...             ...         ...    ...         ...                ...
# 85  success           Spain          ES     CT   Catalonia          Barcelona
# 86  success   United States          US     WA  Washington             Quincy
# 87  success           Spain          ES     MD      Madrid             Madrid
# 88  success           Spain          ES     MD      Madrid             Madrid
# 89  success           Spain          ES     VC    Valencia           Paiporta
#
#       zip      lat         lon                   timezone  \
# 0    5501 -32.9204  -68.829300  America/Argentina/Mendoza
# 1    5501 -32.9204  -68.829300  America/Argentina/Mendoza
# 2   98848  47.2342 -119.852500        America/Los_Angeles
# 3          39.9042  116.407000              Asia/Shanghai
# 4     W1B  51.5074   -0.127758              Europe/London
# ..    ...      ...         ...                        ...
# 85  08001  41.3870    2.170100              Europe/Madrid
# 86  98848  47.2330 -119.852000        America/Los_Angeles
# 87  28049  40.4163   -3.693400              Europe/Madrid
# 88  28760  40.5167   -3.664790              Europe/Madrid
# 89  46200  39.4305   -0.419100              Europe/Madrid
#
#                                           isp  \
# 0                              Alpha Tel S.A.
# 1                              Alpha Tel S.A.
# 2                       Microsoft Corporation
# 3   IDC, China Telecommunications Corporation
# 4                      Pulsant (Scotland) Ltd
# ..                                        ...
# 85                 RIMA (Red IP Multi Acceso)
# 86                      Microsoft Corporation
# 87                   Telefonica de Espana SAU
# 88                   Telefonica de Espana SAU
# 89                   Telefonica de Espana SAU
#
#                                 org  \
# 0                     Alpha Tel S.A
# 1                     Alpha Tel S.A
# 2             Microsoft Corporation
# 3
# 4          Dedipower Dedicated O1fl
# ..                              ...
# 85
# 86  Microsoft Azure Cloud (westus2)
# 87       RIMA (Red IP Multi Acceso)
# 88       RIMA (Red IP Multi Acceso)
# 89     TDENET (Red de servicios IP)
#
#                                                    as            query
# 0                              AS28114 Alpha Tel S.A.    181.118.30.53
# 1                              AS28114 Alpha Tel S.A.    181.118.30.53
# 2                        AS8075 Microsoft Corporation     157.56.93.62
# 3   AS23724 IDC, China Telecommunications Corporation   220.181.108.82
# 4                      AS12703 Pulsant (Scotland) Ltd     46.236.24.53
# ..                                                ...              ...
# 85                        AS3352 TELEFONICA DE ESPANA     80.35.187.33
# 86                       AS8075 Microsoft Corporation    199.30.25.230
# 87                        AS3352 TELEFONICA DE ESPANA    81.39.110.171
# 88                        AS3352 TELEFONICA DE ESPANA       83.46.27.9
# 89                        AS3352 TELEFONICA DE ESPANA  212.170.176.111
#
# [90 rows x 14 columns]

# %% [markdown]
# #### La funció només permet processar les Ips en files de 90

# %% [markdown]
# ### Relacions amb el dataframe principal

# %%
data
# Out:
#                      host             ip http_code response_bytes  url  \
# 0               localhost      127.0.0.1       200            NaN  NaN
# 1               localhost      127.0.0.1       200            NaN  NaN
# 2               localhost      127.0.0.1       200            NaN  NaN
# 3               localhost      127.0.0.1       200            NaN  NaN
# 4               localhost      127.0.0.1       200            NaN  NaN
# ...                   ...            ...       ...            ...  ...
# 261868  www.akumenius.com   5.255.253.53       200           7528  NaN
# 261869  www.akumenius.com  74.86.158.107       200            NaN  NaN
# 261870          localhost      127.0.0.1       200            NaN  NaN
# 261871          localhost      127.0.0.1       200            NaN  NaN
# 261872          localhost      127.0.0.1       200            NaN  NaN
#
#                                                user_agent                time  \
# 0                      Apache (internal dummy connection) 2014-02-23 03:10:31
# 1                      Apache (internal dummy connection) 2014-02-23 03:10:31
# 2                      Apache (internal dummy connection) 2014-02-23 03:10:31
# 3                      Apache (internal dummy connection) 2014-02-23 03:10:31
# 4                      Apache (internal dummy connection) 2014-02-23 03:10:31
# ...                                                   ...                 ...
# 261868  Mozilla/5.0 (compatible; YandexBot/3.0; +http:... 2014-03-02 03:05:39
# 261869  Mozilla/5.0+(compatible; UptimeRobot/2.0; http... 2014-03-02 03:09:52
# 261870                 Apache (internal dummy connection) 2014-03-02 03:10:18
# 261871                 Apache (internal dummy connection) 2014-03-02 03:10:18
# 261872                 Apache (internal dummy connection) 2014-03-02 03:10:18
#
#         command path  protocol
# 0       OPTIONS    *  HTTP/1.0
# 1       OPTIONS    *  HTTP/1.0
# 2       OPTIONS    *  HTTP/1.0
# 3       OPTIONS    *  HTTP/1.0
# 4       OPTIONS    *  HTTP/1.0
# ...         ...  ...       ...
# 261868      GET    /  HTTP/1.1
# 261869     HEAD    /  HTTP/1.1
# 261870  OPTIONS    *  HTTP/1.0
# 261871  OPTIONS    *  HTTP/1.0
# 261872  OPTIONS    *  HTTP/1.0
#
# [261873 rows x 10 columns]

# %%
http_code_host = data.groupby([data.http_code, data.ip]).count()
http_code_host.iloc[:len(http_code_host.index)]
# Out:
#                            host  response_bytes  url  user_agent  time  \
# http_code ip
# 200       107.21.14.116       2               2    0           1     2
#           109.107.105.181    70              70   69          70    70
#           109.120.157.179     2               2    2           2     2
#           109.205.137.141     1               1    0           1     1
#           109.208.120.233     1               1    0           1     1
# ...                         ...             ...  ...         ...   ...
# 408       85.57.252.60        5               0    0           0     5
#           92.58.211.126       5               0    0           0     5
# 500       80.28.221.123       2               0    0           2     2
# 502       176.31.255.177     18              18    0          18    18
#           80.28.221.123       1               1    0           1     1
#
#                            command  path  protocol
# http_code ip
# 200       107.21.14.116          2     2         2
#           109.107.105.181       70    70        70
#           109.120.157.179        2     2         2
#           109.205.137.141        1     1         1
#           109.208.120.233        1     1         1
# ...                            ...   ...       ...
# 408       85.57.252.60           0     0         0
#           92.58.211.126          0     0         0
# 500       80.28.221.123          2     2         2
# 502       176.31.255.177        18    18        18
#           80.28.221.123          1     1         1
#
# [4564 rows x 8 columns]

# %% [markdown]
# ### Nombre de peticions per Ip

# %%
ip = data.groupby([data.ip]).size()

# %%
ip
# Out:
# ip
# 101.199.108.59      32
# 101.226.167.226      1
# 107.178.37.48      194
# 107.178.38.221     176
# 107.21.14.116        2
#                   ...
# 95.63.234.126      265
# 95.63.60.249       154
# 96.242.31.129       52
# 98.137.206.41       11
# 98.244.10.248       91
# Length: 2921, dtype: int64
